# %%
import geopandas as gpd
import pandas as pd
from geopy.distance import great_circle
import requests
import time

# %%
rent_df = pd.read_csv('../../data/landing/cleaned_rent_data.csv')
hospital_df = pd.read_csv('../../data/curated/hospitals.csv')
rent_df['nearestHospital'] = None

# %%
rent_df
# Out:
#        price  bathrooms  bedrooms  parking                     type  \
# 0      750.0          2         2        0  Apartment / Unit / Flat
# 1      625.0          1         1        0  Apartment / Unit / Flat
# 2      620.0          1         1        1  Apartment / Unit / Flat
# 3      550.0          1         1        0  Apartment / Unit / Flat
# 4      525.0          1         1        0  Apartment / Unit / Flat
# ...      ...        ...       ...      ...                      ...
# 11649  420.0          1         3        1                    House
# 11650  550.0          2         3        2                    House
# 11651  450.0          1         3        0                    House
# 11652  435.0          1         3        0                    House
# 11653  350.0          1         1        1                    House
#
#                            street     suburb  postcode   latitude  longitude  \
# 0         403/639 Lonsdale Street  MELBOURNE    3000.0 -37.815010  144.95341
# 1         3409/138 Spencer Street  MELBOURNE    3000.0 -37.817470  144.95366
# 2         103/300 Swanston Street  MELBOURNE    3000.0 -37.810608  144.96458
# 3         801/115 Swanston Street  MELBOURNE    3000.0 -37.814995  144.96603
# 4          808/422 Collins Street  MELBOURNE    3000.0 -37.817097  144.96014
# ...                           ...        ...       ...        ...        ...
# 11649            48 Hunter Street  WONTHAGGI    3995.0 -38.613125  145.58660
# 11650           64 Halford Street  INVERLOCH    3996.0 -38.634730  145.71307
# 11651          35 Anderson Avenue  INVERLOCH    3996.0 -38.629770  145.73927
# 11652            3 Kennards Court  INVERLOCH    3996.0 -38.626730  145.72865
# 11653  Cabin 2/18 Williams Street  INVERLOCH    3996.0 -38.632603  145.73026
#
#                                                   school  furnished  \
# 0      Docklands Primary School1.1 km awayPrep-6CoEdG...       True
# 1      Docklands Primary School1.2 km awayPrep-6CoEdG...       True
# 2      Carlton Gardens Primary School1 km awayPrep-6C...       True
# 3      Carlton Gardens Primary School1.5 km awayPrep-...       True
# 4      Docklands Primary School1.7 km awayPrep-6CoEdG...      False
# ...                                                  ...        ...
# 11649  Wonthaggi Primary School0.6 km awayPrep-6CoEdG...      False
# 11650  Inverloch Primary School1.4 km awayPrep-6CoEdG...      False
# 11651  Inverloch Primary School0.9 km awayPrep-6CoEdG...      False
# 11652  Inverloch Primary School0.5 km awayPrep-6CoEdG...       True
# 11653  Inverloch Primary School0.2 km awayPrep-6CoEdG...       True
#
#           SA2_code nearestHospital
# 0      206041505.0            None
# 1      206041505.0            None
# 2      206041504.0            None
# 3      206041503.0            None
# 4      206041505.0            None
# ...            ...             ...
# 11649  205031093.0            None
# 11650  205031093.0            None
# 11651  205031093.0            None
# 11652  205031093.0            None
# 11653  205031093.0            None
#
# [11654 rows x 14 columns]

# %%
hospital_df
# Out:
#                               Hospital name  Phone number  \
# 0                        Albert Road Clinic  03 9256 8311
# 1    Albury Wodonga Health [Wodonga Campus]  02 6051 7111
# 2               Alexandra District Hospital  03 5772 0900
# 3                    Alpine Health [Bright]  03 5755 0100
# 4              Alpine Health [Mount Beauty]  03 5754 3500
# ..                                      ...           ...
# 233                  Women's at Sandringham  03 9076 1000
# 234                     Yarra Ranges Health  1300 342 255
# 235        Yarram & District Health Service  03 5182 0222
# 236      Yarrawonga District Health Service  03 5743 8111
# 237        Yea & District Memorial Hospital  03 5736 0400
#
#             Street address       Suburb  Postcode State  \
# 0           31 Albert Road    Melbourne      3004   Vic
# 1        69 Vermont Street      Wodonga      3690   Vic
# 2         12 Cooper Street    Alexandra      3714   Vic
# 3      36-42 Cobden Street       Bright      3741   Vic
# 4       10 Hollonds Street    Mt Beauty      3699   Vic
# ..                     ...          ...       ...   ...
# 233         193 Bluff Road  Sandringham      3191   Vic
# 234       25 Market Street     Lilydale      3140   Vic
# 235  85-91 Commercial Road       Yarram      3971   Vic
# 236        33 Piper Street   Yarrawonga      3730   Vic
# 237      45 Station Street          Yea      3717   Vic
#
#            Local Hospital Network (LHN) Primary Health Network area (PHN)  \
# 0                                   NaN                               NaN
# 1                 Albury Wodonga Health                            Murray
# 2           Alexandra District Hospital                            Murray
# 3                   Alpine Health (Vic)                            Murray
# 4                   Alpine Health (Vic)                            Murray
# ..                                  ...                               ...
# 233  Royal Women's Hospital (Melbourne)           South Eastern Melbourne
# 234                Eastern Health (Vic)                 Eastern Melbourne
# 235  Yarram and District Health Service                         Gippsland
# 236  Yarrawonga District Health Service                            Murray
# 237  Yea and District Memorial Hospital                            Murray
#
#                                                Website  \
# 0                         www.albertroadclinic.com.au/
# 1                                                  NaN
# 2                                                  NaN
# 3                              www.alpinehealth.org.au
# 4                              www.alpinehealth.org.au
# ..                                                 ...
# 233  www.thewomens.org.au/health-professionals/mate...
# 234  https://www.easternhealth.org.au/locations/yar...
# 235                                   www.ydhs.com.au/
# 236                              http://www.yh.org.au/
# 237                                                NaN
#
#                                            Description   Sector     Beds  \
# 0                                                  NaN  Private    50-99
# 1    Medium regional hospital with an emergency dep...   Public  100-199
# 2                                       Small hospital   Public      <50
# 3                                       Small hospital   Public      <50
# 4                                    Regional hospital   Public      <50
# ..                                                 ...      ...      ...
# 233                        Specialist women's hospital   Public      <50
# 234                             Day procedure hospital   Public      <50
# 235                                  Regional hospital   Public      <50
# 236                                     Small hospital   Public      <50
# 237                                  Regional hospital   Public      <50
#
#       Latitude   Longitude  Hospital_ID
# 0   -37.834246  144.972151            8
# 1   -36.131791  146.879417           10
# 2   -37.195065  145.716143           12
# 3   -36.732701  146.965924           16
# 4   -36.743354  147.169359           17
# ..         ...         ...          ...
# 233 -37.961049  145.018157          995
# 234 -37.756319  145.351204         1005
# 235 -38.556975  146.678316         1006
# 236 -36.011547  146.006584         1007
# 237 -37.213634  145.430724         1009
#
# [238 rows x 15 columns]

# %%
def the_nearest_location(rentDf, locationDf, locationName):
    """ 
    Function to find the nearest location (e.g., hospital, school)
    Parameters: 
        rentDf: DataFrame containing properties with latitude and longitude.
        locationDf: DataFrame containing locations (e.g., hospitals) with latitude and longitude.
        locationName: The column name to store the nearest location information.
    
    Return: 
        Updated DataFrame with nearest location and distance added in the specified column.
    """
    # Loop through each property in rentDf
    for index, row in rentDf.iterrows():
        point1 = (row['latitude'], row['longitude'])  # Property's coordinates
        min_distance = float('inf')  # Set initial minimum distance to infinity
        nearest_location = None  # Store nearest location's coordinates

        # Loop through each location in locationDf to calculate the distance
        for index2, row2 in locationDf.iterrows():
            point2 = (row2['Latitude'], row2['Longitude'])  # Location's coordinates
            distance = great_circle(point1, point2).kilometers  # Calculate distance using great_circle
            
            # Update minimum distance if a closer location is found
            if distance < min_distance:
                min_distance = distance
                nearest_location = point2

        # Create a dictionary to store nearest location information
        info_dict = {
            'dist': min_distance,
            'nearest_coord': nearest_location
        }

        # Update rentDf with the nearest location information
        rentDf.at[index, locationName] = info_dict

    return rentDf

# %%
rent_df = the_nearest_location(rent_df, hospital_df, 'nearestHospital')

# %%
rent_df['hospital_distance'] = None
rent_df['to_hospital_time'] = None

# %%
rent_df
# Out:
#        price  bathrooms  bedrooms  parking                     type  \
# 0      750.0          2         2        0  Apartment / Unit / Flat
# 1      625.0          1         1        0  Apartment / Unit / Flat
# 2      620.0          1         1        1  Apartment / Unit / Flat
# 3      550.0          1         1        0  Apartment / Unit / Flat
# 4      525.0          1         1        0  Apartment / Unit / Flat
# ...      ...        ...       ...      ...                      ...
# 11649  420.0          1         3        1                    House
# 11650  550.0          2         3        2                    House
# 11651  450.0          1         3        0                    House
# 11652  435.0          1         3        0                    House
# 11653  350.0          1         1        1                    House
#
#                            street     suburb  postcode   latitude  longitude  \
# 0         403/639 Lonsdale Street  MELBOURNE    3000.0 -37.815010  144.95341
# 1         3409/138 Spencer Street  MELBOURNE    3000.0 -37.817470  144.95366
# 2         103/300 Swanston Street  MELBOURNE    3000.0 -37.810608  144.96458
# 3         801/115 Swanston Street  MELBOURNE    3000.0 -37.814995  144.96603
# 4          808/422 Collins Street  MELBOURNE    3000.0 -37.817097  144.96014
# ...                           ...        ...       ...        ...        ...
# 11649            48 Hunter Street  WONTHAGGI    3995.0 -38.613125  145.58660
# 11650           64 Halford Street  INVERLOCH    3996.0 -38.634730  145.71307
# 11651          35 Anderson Avenue  INVERLOCH    3996.0 -38.629770  145.73927
# 11652            3 Kennards Court  INVERLOCH    3996.0 -38.626730  145.72865
# 11653  Cabin 2/18 Williams Street  INVERLOCH    3996.0 -38.632603  145.73026
#
#                                                   school  furnished  \
# 0      Docklands Primary School1.1 km awayPrep-6CoEdG...       True
# 1      Docklands Primary School1.2 km awayPrep-6CoEdG...       True
# 2      Carlton Gardens Primary School1 km awayPrep-6C...       True
# 3      Carlton Gardens Primary School1.5 km awayPrep-...       True
# 4      Docklands Primary School1.7 km awayPrep-6CoEdG...      False
# ...                                                  ...        ...
# 11649  Wonthaggi Primary School0.6 km awayPrep-6CoEdG...      False
# 11650  Inverloch Primary School1.4 km awayPrep-6CoEdG...      False
# 11651  Inverloch Primary School0.9 km awayPrep-6CoEdG...      False
# 11652  Inverloch Primary School0.5 km awayPrep-6CoEdG...       True
# 11653  Inverloch Primary School0.2 km awayPrep-6CoEdG...       True
#
#           SA2_code                                    nearestHospital  \
# 0      206041505.0  {'dist': 0.34167395403372697, 'nearest_coord':...
# 1      206041505.0  {'dist': 0.5822133115824419, 'nearest_coord': ...
# 2      206041504.0  {'dist': 0.7376496705051538, 'nearest_coord': ...
# 3      206041503.0  {'dist': 0.47429311644965033, 'nearest_coord':...
# 4      206041505.0  {'dist': 0.9547837766075489, 'nearest_coord': ...
# ...            ...                                                ...
# 11649  205031093.0  {'dist': 0.6940849282484552, 'nearest_coord': ...
# 11650  205031093.0  {'dist': 11.839661644936594, 'nearest_coord': ...
# 11651  205031093.0  {'dist': 13.955512102405784, 'nearest_coord': ...
# 11652  205031093.0  {'dist': 12.9907802359375, 'nearest_coord': (-...
# 11653  205031093.0  {'dist': 13.243685841653544, 'nearest_coord': ...
#
#       hospital_distance to_hospital_time
# 0                  None             None
# 1                  None             None
# 2                  None             None
# 3                  None             None
# 4                  None             None
# ...                 ...              ...
# 11649              None             None
# 11650              None             None
# 11651              None             None
# 11652              None             None
# 11653              None             None
#
# [11654 rows x 16 columns]

# %%
hospital_df
# Out:
#                               Hospital name  Phone number  \
# 0                        Albert Road Clinic  03 9256 8311
# 1    Albury Wodonga Health [Wodonga Campus]  02 6051 7111
# 2               Alexandra District Hospital  03 5772 0900
# 3                    Alpine Health [Bright]  03 5755 0100
# 4              Alpine Health [Mount Beauty]  03 5754 3500
# ..                                      ...           ...
# 233                  Women's at Sandringham  03 9076 1000
# 234                     Yarra Ranges Health  1300 342 255
# 235        Yarram & District Health Service  03 5182 0222
# 236      Yarrawonga District Health Service  03 5743 8111
# 237        Yea & District Memorial Hospital  03 5736 0400
#
#             Street address       Suburb  Postcode State  \
# 0           31 Albert Road    Melbourne      3004   Vic
# 1        69 Vermont Street      Wodonga      3690   Vic
# 2         12 Cooper Street    Alexandra      3714   Vic
# 3      36-42 Cobden Street       Bright      3741   Vic
# 4       10 Hollonds Street    Mt Beauty      3699   Vic
# ..                     ...          ...       ...   ...
# 233         193 Bluff Road  Sandringham      3191   Vic
# 234       25 Market Street     Lilydale      3140   Vic
# 235  85-91 Commercial Road       Yarram      3971   Vic
# 236        33 Piper Street   Yarrawonga      3730   Vic
# 237      45 Station Street          Yea      3717   Vic
#
#            Local Hospital Network (LHN) Primary Health Network area (PHN)  \
# 0                                   NaN                               NaN
# 1                 Albury Wodonga Health                            Murray
# 2           Alexandra District Hospital                            Murray
# 3                   Alpine Health (Vic)                            Murray
# 4                   Alpine Health (Vic)                            Murray
# ..                                  ...                               ...
# 233  Royal Women's Hospital (Melbourne)           South Eastern Melbourne
# 234                Eastern Health (Vic)                 Eastern Melbourne
# 235  Yarram and District Health Service                         Gippsland
# 236  Yarrawonga District Health Service                            Murray
# 237  Yea and District Memorial Hospital                            Murray
#
#                                                Website  \
# 0                         www.albertroadclinic.com.au/
# 1                                                  NaN
# 2                                                  NaN
# 3                              www.alpinehealth.org.au
# 4                              www.alpinehealth.org.au
# ..                                                 ...
# 233  www.thewomens.org.au/health-professionals/mate...
# 234  https://www.easternhealth.org.au/locations/yar...
# 235                                   www.ydhs.com.au/
# 236                              http://www.yh.org.au/
# 237                                                NaN
#
#                                            Description   Sector     Beds  \
# 0                                                  NaN  Private    50-99
# 1    Medium regional hospital with an emergency dep...   Public  100-199
# 2                                       Small hospital   Public      <50
# 3                                       Small hospital   Public      <50
# 4                                    Regional hospital   Public      <50
# ..                                                 ...      ...      ...
# 233                        Specialist women's hospital   Public      <50
# 234                             Day procedure hospital   Public      <50
# 235                                  Regional hospital   Public      <50
# 236                                     Small hospital   Public      <50
# 237                                  Regional hospital   Public      <50
#
#       Latitude   Longitude  Hospital_ID
# 0   -37.834246  144.972151            8
# 1   -36.131791  146.879417           10
# 2   -37.195065  145.716143           12
# 3   -36.732701  146.965924           16
# 4   -36.743354  147.169359           17
# ..         ...         ...          ...
# 233 -37.961049  145.018157          995
# 234 -37.756319  145.351204         1005
# 235 -38.556975  146.678316         1006
# 236 -36.011547  146.006584         1007
# 237 -37.213634  145.430724         1009
#
# [238 rows x 15 columns]

# %% [markdown]
# # Calculate distances using the OpenRoute Service
# ### Due to the API request limitations (2000 requests per day, 40 per minute), we decided to divide the properties into 5 subsets. Each member will be responsible for calculating the distances individually using their own account.
#
# ### Please note that in the code below, we are working with the entire dataset, and once the loop reaches 2000 requests, an API request error will occur.

# %%
import time
import requests
import pandas as pd
import os

# Your API key (hidden for security reasons)
your_api = os.getenv('ORS_API_KEY')  # Use environment variable to store the API key

# API request limit parameters
max_per_Min = 40
time_sleep = 60 / max_per_Min

# Define the batch range, for example [1, 2000]
start = 10001
end = 11655

# Ensure the save file path exists
output_dir = '../../data/External_data/'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)  # Create directory if it does not exist

# Iterate over each entry in the rental dataset for the specified index range
for index, row in rent_df.iloc[start-1:end].iterrows():  # Note iloc starts at 0, so start-1
    if pd.isna(row['hospital_distance']):  # Only process records where hospital_distance is empty
        longi = row['longitude']
        latit = row['latitude']

        # Get the coordinates of the nearest hospital
        nearest_hospital_info = row['nearestHospital']
        if nearest_hospital_info and 'nearest_coord' in nearest_hospital_info:
            hospital_longi = nearest_hospital_info['nearest_coord'][1]  # Longitude
            hospital_latit = nearest_hospital_info['nearest_coord'][0]  # Latitude

            # Construct the API request URL
            api_url = f'https://api.openrouteservice.org/v2/directions/driving-car?api_key={your_api}&start={longi},{latit}&end={hospital_longi},{hospital_latit}'

            try:
                # Send the API request
                response = requests.get(api_url)

                # Check the request status
                if response.status_code == 200:
                    info = response.json()

                    # Parse the API response
                    features = info.get('features', [])
                    if features:
                        summary = features[0]['properties']['summary']  # Get driving route information
                        distance = summary['distance']  # Distance, in meters
                        duration_time = summary['duration']  # Driving time, in seconds

                        # Update rent_df with hospital_distance and to_hospital_time
                        rent_df.at[index, 'hospital_distance'] = distance
                        rent_df.at[index, 'to_hospital_time'] = duration_time
                else:
                    print(f"Request failed with status code: {response.status_code}")

            except requests.exceptions.RequestException as e:
                print(f"API request failed: {e}")

            # Limit the API request rate
            time.sleep(time_sleep)

    else:
        continue

# Save the current batch of data to the specified directory
output_file = f'{output_dir}rent_data_{start}_to_{end}.csv'
rent_df.iloc[start-1:end].to_csv(output_file, index=False)

print(f'Data saved to {output_file}')
