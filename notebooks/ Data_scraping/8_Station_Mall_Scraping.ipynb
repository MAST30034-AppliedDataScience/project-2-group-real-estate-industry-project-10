# %%
import googlemaps
import time
import csv
import json
import os
import numpy as np  # To use np.arange() for floating-point steps

# Initialize the client with your API key
gmaps = googlemaps.Client(key='AIzaSyAW6asiXdtzR_881ONGwA5dHJkol8msgCc')

# Define the latitude and longitude bounds for Victoria
min_latitude = -39.0
max_latitude = -33.0
min_longitude = 141.0
max_longitude = 150.0

# Define the step size (degree of latitude/longitude) for the grid
step_size = 0.2  # Adjust this as needed

# Initialize a list to store the shopping mall locations
train_station_locations = []

# Create the directory if it doesn't exist
output_dir = "../data/landing/External_data"
os.makedirs(output_dir, exist_ok=True)

# Loop over the grid using np.arange for floating-point steps
latitudes = np.arange(min_latitude, max_latitude, step_size)
longitudes = np.arange(min_longitude, max_longitude, step_size)

for current_lat in latitudes:
    for current_lng in longitudes:
        
        # Define the location for the API request
        location = (current_lat, current_lng)
        
        # Search for nearby shopping malls
        try:
            train_stations = gmaps.places_nearby(location=location, radius=5000, type='train_station')
            
            # Append the results to the list
            for place in train_stations['results']:
                name = place['name']
                lat = place['geometry']['location']['lat']
                lng = place['geometry']['location']['lng']
                train_station_locations.append({'name': name, 'latitude': lat, 'longitude': lng})
                print(f'Found: {name}, Latitude: {lat}, Longitude: {lng}')
        
        except googlemaps.exceptions.ApiError as e:
            print(f"API error: {e}")
        except Exception as e:
            print(f"An error occurred: {e}")
        
        # Sleep to avoid hitting the API rate limit
        time.sleep(1)  # Adjust sleep time as needed
# Out:
# Found: Stony Point, Latitude: -38.37406889999999, Longitude: 145.2216987
# Found: Crib Point Station, Latitude: -38.36598369999999, Longitude: 145.2041561
# Found: Korumburra, Latitude: -38.43083599999999, Longitude: 145.8238718
# Found: Winchelsea Railway Station, Latitude: -38.2401679, Longitude: 143.9837612
# Found: Marshall Railway Station (Marshall), Latitude: -38.19871009999999, Longitude: 144.3550024
# Found: Drysdale, Latitude: -38.1800466, Longitude: 144.5575192
# Found: Somerville Station, Latitude: -38.2253862, Longitude: 145.1763333
# Found: Baxter Station, Latitude: -38.1940741, Longitude: 145.1605053
# Found: Darnum, Latitude: -38.18625749999999, Longitude: 146.0033629
# Found: Trafalgar, Latitude: -38.2074386, Longitude: 146.1548924
# Found: Morwell Railway Station (Morwell), Latitude: -38.23675809999999, Longitude: 146.3972369
# Found: Rosedale Station, Latitude: -38.15631339999999, Longitude: 146.7871525
# ...

# %%
# Write the data to a CSV file
output_dir = "../data/landing/External_data"
os.makedirs(output_dir, exist_ok=True)

csv_file = os.path.join(output_dir, "train_stations_victoria.csv")
with open(csv_file, mode='w', newline='') as file:
    writer = csv.DictWriter(file, fieldnames=['name', 'latitude', 'longitude'])
    writer.writeheader()
    for station in train_station_locations:
        writer.writerow(station)

# %%
import googlemaps
import time
import csv
import json
import os
import numpy as np  # To use np.arange() for floating-point steps

# Initialize the client with your API key
gmaps = googlemaps.Client(key='AIzaSyAW6asiXdtzR_881ONGwA5dHJkol8msgCc')

# Define the latitude and longitude bounds for Victoria
min_latitude = -39.0
max_latitude = -33.0
min_longitude = 141.0
max_longitude = 150.0

# Define the step size (degree of latitude/longitude) for the grid
step_size = 0.2  # Adjust this as needed

# Initialize a list to store the shopping mall locations
shopping_mall_locations = []

# Create the directory if it doesn't exist
output_dir = "../data/landing/External_data"
os.makedirs(output_dir, exist_ok=True)

# Loop over the grid using np.arange for floating-point steps
latitudes = np.arange(min_latitude, max_latitude, step_size)
longitudes = np.arange(min_longitude, max_longitude, step_size)

for current_lat in latitudes:
    for current_lng in longitudes:
        
        # Define the location for the API request
        location = (current_lat, current_lng)
        
        # Search for nearby shopping malls
        try:
            shopping_malls = gmaps.places_nearby(location=location, radius=5000, type='shopping_mall')
            
            # Append the results to the list
            for place in shopping_malls['results']:
                name = place['name']
                lat = place['geometry']['location']['lat']
                lng = place['geometry']['location']['lng']
                shopping_mall_locations.append({'name': name, 'latitude': lat, 'longitude': lng})
                print(f'Found: {name}, Latitude: {lat}, Longitude: {lng}')
        
        except googlemaps.exceptions.ApiError as e:
            print(f"API error: {e}")
        except Exception as e:
            print(f"An error occurred: {e}")
        
        # Sleep to avoid hitting the API rate limit
        time.sleep(1)  # Adjust sleep time as needed
# Out:
# Found: Port Campbell Lolly Shop, Latitude: -38.6201077, Longitude: 142.9949696
# Found: Bass Coast Plaza, Latitude: -38.6033035, Longitude: 145.5890158
# Found: Wonthaggi Plaza, Latitude: -38.6038571, Longitude: 145.5875053
# Found: Murray Street Bazaar, Latitude: -38.604944, Longitude: 145.5930667
# Found: Plaza Arcade, Latitude: -38.6060048, Longitude: 145.5898668
# Found: Organic Lifestyle Blog, Latitude: -38.4192541, Longitude: 143.9483938
# Found: The Crystal Cocoon, Latitude: -38.43158880000001, Longitude: 145.8230172
# Found: Into The Rabbit Hole, Latitude: -38.43158880000001, Longitude: 145.8230172
# Found: Korumburra Makers & Collectors, Latitude: -38.4324616, Longitude: 145.823914
# Found: Newcomb Central Shopping Centre, Latitude: -38.1700271, Longitude: 144.3926735
# Found: Bellarine Village Shopping Centre, Latitude: -38.1687151, Longitude: 144.3887315
# Found: The Village Warralily Shopping Centre, Latitude: -38.2300895, Longitude: 144.3722798
# ...

# %%
# Write the data to a CSV file
output_dir = "../data/landing/External_data"
os.makedirs(output_dir, exist_ok=True)

csv_file = os.path.join(output_dir, "shopping_mall_locations.csv")
with open(csv_file, mode='w', newline='') as file:
    writer = csv.DictWriter(file, fieldnames=['name', 'latitude', 'longitude'])
    writer.writeheader()
    for mall in shopping_mall_locations:
        writer.writerow(mall)
